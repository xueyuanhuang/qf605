# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# # part i q1

# %%
ois = pd.read_excel("IR Data.xlsx", sheet_name = 'OIS', usecols = ["Tenor", "Product", "Rate"])
ois
# Out:
#    Tenor Product     Rate
# 0     6m     OIS  0.00250
# 1     1y     OIS  0.00300
# 2     2y     OIS  0.00325
# 3     3y     OIS  0.00335
# 4     4y     OIS  0.00350
# 5     5y     OIS  0.00360
# 6     7y     OIS  0.00400
# 7    10y     OIS  0.00450
# 8    15y     OIS  0.00500
# 9    20y     OIS  0.00525
# 10   30y     OIS  0.00550

# %%
#tenors = ['6m', '1y', '2y', '3y', '4y', '5y', '7y', '10y', '15y', '20y', '30y']
tenors = ois["Tenor"]

# Define a function to convert tenor strings to days
def tenor_to_days(tenor):
    if 'm' in tenor:
        return int(tenor.replace('m', '')) * 30
    elif 'y' in tenor:
        return int(tenor.replace('y', '')) * 360
    else:
        return None

def tenor_to_years(tenor):
    if 'm' in tenor:
        return int(tenor.replace('m', '')) / 12
    elif 'y' in tenor:
        return int(tenor.replace('y', ''))
    else:
        return None

# Convert each tenor to days
ois["days"] = [tenor_to_days(tenor) for tenor in tenors]
ois["years"] = [tenor_to_years(tenor) for tenor in tenors]
ois
# Out:
#    Tenor Product     Rate   days  years
# 0     6m     OIS  0.00250    180    0.5
# 1     1y     OIS  0.00300    360    1.0
# 2     2y     OIS  0.00325    720    2.0
# 3     3y     OIS  0.00335   1080    3.0
# 4     4y     OIS  0.00350   1440    4.0
# 5     5y     OIS  0.00360   1800    5.0
# 6     7y     OIS  0.00400   2520    7.0
# 7    10y     OIS  0.00450   3600   10.0
# 8    15y     OIS  0.00500   5400   15.0
# 9    20y     OIS  0.00525   7200   20.0
# 10   30y     OIS  0.00550  10800   30.0

# %%
ois1 = ois.copy()
ois1[['sum_df','df']] = np.nan
ois1
# Out:
#    Tenor Product     Rate   days  years  sum_df  df
# 0     6m     OIS  0.00250    180    0.5     NaN NaN
# 1     1y     OIS  0.00300    360    1.0     NaN NaN
# 2     2y     OIS  0.00325    720    2.0     NaN NaN
# 3     3y     OIS  0.00335   1080    3.0     NaN NaN
# 4     4y     OIS  0.00350   1440    4.0     NaN NaN
# 5     5y     OIS  0.00360   1800    5.0     NaN NaN
# 6     7y     OIS  0.00400   2520    7.0     NaN NaN
# 7    10y     OIS  0.00450   3600   10.0     NaN NaN
# 8    15y     OIS  0.00500   5400   15.0     NaN NaN
# 9    20y     OIS  0.00525   7200   20.0     NaN NaN
# 10   30y     OIS  0.00550  10800   30.0     NaN NaN

# %%
def equation1(df, rate):
    return rate*df - (1 - df)
    
guess = 0.99

ois1.at[1, 'df'] = fsolve(equation1, guess, args=(ois1.at[1, 'Rate']))[0]
ois1.at[1, 'sum_df'] = ois1.at[1, 'df']
ois1
# Out:
#    Tenor Product     Rate   days  years    sum_df        df
# 0     6m     OIS  0.00250    180    0.5       NaN       NaN
# 1     1y     OIS  0.00300    360    1.0  0.997009  0.997009
# 2     2y     OIS  0.00325    720    2.0       NaN       NaN
# 3     3y     OIS  0.00335   1080    3.0       NaN       NaN
# 4     4y     OIS  0.00350   1440    4.0       NaN       NaN
# 5     5y     OIS  0.00360   1800    5.0       NaN       NaN
# 6     7y     OIS  0.00400   2520    7.0       NaN       NaN
# 7    10y     OIS  0.00450   3600   10.0       NaN       NaN
# 8    15y     OIS  0.00500   5400   15.0       NaN       NaN
# 9    20y     OIS  0.00525   7200   20.0       NaN       NaN
# 10   30y     OIS  0.00550  10800   30.0       NaN       NaN

# %%
def equation2(df, rate, ois_df):
    return rate*(df + ois_df.sum()) - (1 - df)
    
for i in range(2, 6):
    ois1.at[i, 'df'] = fsolve(equation2, guess, args=(ois1.at[i, 'Rate'], ois1["df"]))[0]
    ois1.at[i, 'sum_df'] = ois1.at[i, 'df'] + ois1.at[i-1, 'sum_df']
ois1
# Out:
#    Tenor Product     Rate   days  years    sum_df        df
# 0     6m     OIS  0.00250    180    0.5       NaN       NaN
# 1     1y     OIS  0.00300    360    1.0  0.997009  0.997009
# 2     2y     OIS  0.00325    720    2.0  1.990540  0.993531
# 3     3y     OIS  0.00335   1080    3.0  2.980555  0.990015
# 4     4y     OIS  0.00350   1440    4.0  3.966672  0.986117
# 5     5y     OIS  0.00360   1800    5.0  4.948856  0.982184
# 6     7y     OIS  0.00400   2520    7.0       NaN       NaN
# 7    10y     OIS  0.00450   3600   10.0       NaN       NaN
# 8    15y     OIS  0.00500   5400   15.0       NaN       NaN
# 9    20y     OIS  0.00525   7200   20.0       NaN       NaN
# 10   30y     OIS  0.00550  10800   30.0       NaN       NaN

# %%
def equation3(df, rate, i, ois1):
    sum1 = ois1.at[i-1,'sum_df']
    sum2 = (ois1.at[i, 'years']-ois1.at[i-1, 'years']+1)*(df + ois1.at[i-1,'df'])/2 - ois1.at[i-1, 'df']
    return rate*(sum1 + sum2) - (1 - df)

for i in range(6, len(ois1)):
    
    ois1.at[i, 'df'] = fsolve(equation3, guess, args=(ois1.at[i, 'Rate'], i, ois1))[0]

    sum2 = (ois1.at[i, 'years']-ois1.at[i-1, 'years']+1)*(ois1.at[i,'df'] + ois1.at[i-1,'df'])/2 - ois1.at[i-1, 'df']
    
    ois1.at[i, 'sum_df'] = sum2 + ois1.at[i-1, 'sum_df']
ois1
# Out:
#    Tenor Product     Rate   days  years     sum_df        df
# 0     6m     OIS  0.00250    180    0.5        NaN       NaN
# 1     1y     OIS  0.00300    360    1.0   0.997009  0.997009
# 2     2y     OIS  0.00325    720    2.0   1.990540  0.993531
# 3     3y     OIS  0.00335   1080    3.0   2.980555  0.990015
# 4     4y     OIS  0.00350   1440    4.0   3.966672  0.986117
# 5     5y     OIS  0.00360   1800    5.0   4.948856  0.982184
# 6     7y     OIS  0.00400   2520    7.0   6.898556  0.972406
# 7    10y     OIS  0.00450   3600   10.0   9.782916  0.955977
# 8    15y     OIS  0.00500   5400   15.0  14.477704  0.927611
# 9    20y     OIS  0.00525   7200   20.0  19.033155  0.900076
# 10   30y     OIS  0.00550  10800   30.0  27.744234  0.847407

# %%
def equation4(df, rate, years):
    return years*rate*df - (1 - df)
guess = 0.99

ois1.at[0, 'df'] = fsolve(equation4, guess, args=(ois1.at[0, 'Rate'], ois1.at[0, 'years']))[0]
ois1
# Out:
#    Tenor Product     Rate   days  years     sum_df        df
# 0     6m     OIS  0.00250    180    0.5        NaN  0.998752
# 1     1y     OIS  0.00300    360    1.0   0.997009  0.997009
# 2     2y     OIS  0.00325    720    2.0   1.990540  0.993531
# 3     3y     OIS  0.00335   1080    3.0   2.980555  0.990015
# 4     4y     OIS  0.00350   1440    4.0   3.966672  0.986117
# 5     5y     OIS  0.00360   1800    5.0   4.948856  0.982184
# 6     7y     OIS  0.00400   2520    7.0   6.898556  0.972406
# 7    10y     OIS  0.00450   3600   10.0   9.782916  0.955977
# 8    15y     OIS  0.00500   5400   15.0  14.477704  0.927611
# 9    20y     OIS  0.00525   7200   20.0  19.033155  0.900076
# 10   30y     OIS  0.00550  10800   30.0  27.744234  0.847407

# %%
ois2 = ois1[["years", 'Rate', 'df']].copy()

# Generate the full sequence
full_sequence = np.arange(0.5, 30.5, 0.5)
# Convert 'years' column of your DataFrame to a list
existing_years = ois2['years'].tolist()
# Remove the existing years from the full sequence
new_years = [year for year in full_sequence if year not in existing_years]

additional_years = pd.DataFrame({
    'years': new_years,
    'Rate': [np.nan]*len(new_years),
    'df': [np.nan]*len(new_years)
})
ois2 = pd.concat([additional_years, ois2])
ois2 = ois2.sort_values(by='years')
ois2
# Out:
#     years     Rate        df
# 0     0.5  0.00250  0.998752
# 1     1.0  0.00300  0.997009
# 0     1.5      NaN       NaN
# 2     2.0  0.00325  0.993531
# 1     2.5      NaN       NaN
# 3     3.0  0.00335  0.990015
# 2     3.5      NaN       NaN
# 4     4.0  0.00350  0.986117
# 3     4.5      NaN       NaN
# 5     5.0  0.00360  0.982184
# 4     5.5      NaN       NaN
# 5     6.0      NaN       NaN
# 6     6.5      NaN       NaN
# 6     7.0  0.00400  0.972406
# 7     7.5      NaN       NaN
# 8     8.0      NaN       NaN
# 9     8.5      NaN       NaN
# 10    9.0      NaN       NaN
# 11    9.5      NaN       NaN
# 7    10.0  0.00450  0.955977
# 12   10.5      NaN       NaN
# 13   11.0      NaN       NaN
# 14   11.5      NaN       NaN
# 15   12.0      NaN       NaN
# 16   12.5      NaN       NaN
# 17   13.0      NaN       NaN
# 18   13.5      NaN       NaN
# 19   14.0      NaN       NaN
# 20   14.5      NaN       NaN
# 8    15.0  0.00500  0.927611
# 21   15.5      NaN       NaN
# 22   16.0      NaN       NaN
# 23   16.5      NaN       NaN
# 24   17.0      NaN       NaN
# 25   17.5      NaN       NaN
# 26   18.0      NaN       NaN
# 27   18.5      NaN       NaN
# 28   19.0      NaN       NaN
# 29   19.5      NaN       NaN
# 9    20.0  0.00525  0.900076
# 30   20.5      NaN       NaN
# 31   21.0      NaN       NaN
# 32   21.5      NaN       NaN
# 33   22.0      NaN       NaN
# 34   22.5      NaN       NaN
# 35   23.0      NaN       NaN
# 36   23.5      NaN       NaN
# 37   24.0      NaN       NaN
# 38   24.5      NaN       NaN
# 39   25.0      NaN       NaN
# 40   25.5      NaN       NaN
# 41   26.0      NaN       NaN
# 42   26.5      NaN       NaN
# 43   27.0      NaN       NaN
# 44   27.5      NaN       NaN
# 45   28.0      NaN       NaN
# 46   28.5      NaN       NaN
# 47   29.0      NaN       NaN
# 48   29.5      NaN       NaN
# 10   30.0  0.00550  0.847407

# %%
ois2 = ois2.interpolate(method='linear')
ois2
# Out:
#     years      Rate        df
# 0     0.5  0.002500  0.998752
# 1     1.0  0.003000  0.997009
# 0     1.5  0.003125  0.995270
# 2     2.0  0.003250  0.993531
# 1     2.5  0.003300  0.991773
# 3     3.0  0.003350  0.990015
# 2     3.5  0.003425  0.988066
# 4     4.0  0.003500  0.986117
# 3     4.5  0.003550  0.984150
# 5     5.0  0.003600  0.982184
# 4     5.5  0.003700  0.979740
# 5     6.0  0.003800  0.977295
# 6     6.5  0.003900  0.974850
# 6     7.0  0.004000  0.972406
# 7     7.5  0.004083  0.969668
# 8     8.0  0.004167  0.966929
# 9     8.5  0.004250  0.964191
# 10    9.0  0.004333  0.961453
# 11    9.5  0.004417  0.958715
# 7    10.0  0.004500  0.955977
# 12   10.5  0.004550  0.953140
# 13   11.0  0.004600  0.950304
# 14   11.5  0.004650  0.947467
# 15   12.0  0.004700  0.944631
# 16   12.5  0.004750  0.941794
# 17   13.0  0.004800  0.938958
# 18   13.5  0.004850  0.936121
# 19   14.0  0.004900  0.933285
# 20   14.5  0.004950  0.930448
# 8    15.0  0.005000  0.927611
# 21   15.5  0.005025  0.924858
# 22   16.0  0.005050  0.922104
# 23   16.5  0.005075  0.919351
# 24   17.0  0.005100  0.916597
# 25   17.5  0.005125  0.913844
# 26   18.0  0.005150  0.911090
# 27   18.5  0.005175  0.908337
# 28   19.0  0.005200  0.905583
# 29   19.5  0.005225  0.902829
# 9    20.0  0.005250  0.900076
# 30   20.5  0.005263  0.897442
# 31   21.0  0.005275  0.894809
# 32   21.5  0.005288  0.892176
# 33   22.0  0.005300  0.889542
# 34   22.5  0.005313  0.886909
# 35   23.0  0.005325  0.884275
# 36   23.5  0.005338  0.881642
# 37   24.0  0.005350  0.879008
# 38   24.5  0.005363  0.876375
# 39   25.0  0.005375  0.873741
# 40   25.5  0.005387  0.871108
# 41   26.0  0.005400  0.868474
# 42   26.5  0.005412  0.865841
# 43   27.0  0.005425  0.863207
# 44   27.5  0.005437  0.860574
# 45   28.0  0.005450  0.857941
# 46   28.5  0.005462  0.855307
# 47   29.0  0.005475  0.852674
# 48   29.5  0.005487  0.850040
# 10   30.0  0.005500  0.847407

# %% [markdown]
# # part i q2

# %%
irs = pd.read_excel("IR Data.xlsx", sheet_name = 'IRS', usecols = ["Tenor", "Product", "Rate"])
irs["tenor"] = [tenor_to_years(tenor) for tenor in irs["Tenor"]]

irs1 = irs[['tenor', 'Rate']].copy()
# Generate the full sequence
full_sequence = np.arange(0.5, 30.5, 0.5)
# Convert 'years' column of your DataFrame to a list
existing_tenor = irs1['tenor'].tolist()
# Remove the existing years from the full sequence
new_tenor = [tenor for tenor in full_sequence if tenor not in existing_tenor]

additional_tenor = pd.DataFrame({
    'tenor': new_tenor,
    'Rate': [np.nan]*len(new_tenor),
})
irs1 = pd.concat([additional_tenor, irs1])
irs1 = irs1.sort_values(by='tenor')
irs1['ois_df'] = ois2['df']
irs1['libor_df'] = np.nan
irs1 = irs1.reset_index(drop=True)
irs1
# Out:
#     tenor    Rate    ois_df  libor_df
# 0     0.5  0.0250  0.998752       NaN
# 1     1.0  0.0280  0.997009       NaN
# 2     1.5     NaN  0.995270       NaN
# 3     2.0  0.0300  0.993531       NaN
# 4     2.5     NaN  0.991773       NaN
# 5     3.0  0.0315  0.990015       NaN
# 6     3.5     NaN  0.988066       NaN
# 7     4.0  0.0325  0.986117       NaN
# 8     4.5     NaN  0.984150       NaN
# 9     5.0  0.0330  0.982184       NaN
# 10    5.5     NaN  0.979740       NaN
# 11    6.0     NaN  0.977295       NaN
# 12    6.5     NaN  0.974850       NaN
# 13    7.0  0.0350  0.972406       NaN
# 14    7.5     NaN  0.969668       NaN
# 15    8.0     NaN  0.966929       NaN
# 16    8.5     NaN  0.964191       NaN
# 17    9.0     NaN  0.961453       NaN
# 18    9.5     NaN  0.958715       NaN
# 19   10.0  0.0370  0.955977       NaN
# 20   10.5     NaN  0.953140       NaN
# 21   11.0     NaN  0.950304       NaN
# 22   11.5     NaN  0.947467       NaN
# 23   12.0     NaN  0.944631       NaN
# 24   12.5     NaN  0.941794       NaN
# 25   13.0     NaN  0.938958       NaN
# 26   13.5     NaN  0.936121       NaN
# 27   14.0     NaN  0.933285       NaN
# 28   14.5     NaN  0.930448       NaN
# 29   15.0  0.0400  0.927611       NaN
# 30   15.5     NaN  0.924858       NaN
# 31   16.0     NaN  0.922104       NaN
# 32   16.5     NaN  0.919351       NaN
# 33   17.0     NaN  0.916597       NaN
# 34   17.5     NaN  0.913844       NaN
# 35   18.0     NaN  0.911090       NaN
# 36   18.5     NaN  0.908337       NaN
# 37   19.0     NaN  0.905583       NaN
# 38   19.5     NaN  0.902829       NaN
# 39   20.0  0.0450  0.900076       NaN
# 40   20.5     NaN  0.897442       NaN
# 41   21.0     NaN  0.894809       NaN
# 42   21.5     NaN  0.892176       NaN
# 43   22.0     NaN  0.889542       NaN
# 44   22.5     NaN  0.886909       NaN
# 45   23.0     NaN  0.884275       NaN
# 46   23.5     NaN  0.881642       NaN
# 47   24.0     NaN  0.879008       NaN
# 48   24.5     NaN  0.876375       NaN
# 49   25.0     NaN  0.873741       NaN
# 50   25.5     NaN  0.871108       NaN
# 51   26.0     NaN  0.868474       NaN
# 52   26.5     NaN  0.865841       NaN
# 53   27.0     NaN  0.863207       NaN
# 54   27.5     NaN  0.860574       NaN
# 55   28.0     NaN  0.857941       NaN
# 56   28.5     NaN  0.855307       NaN
# 57   29.0     NaN  0.852674       NaN
# 58   29.5     NaN  0.850040       NaN
# 59   30.0  0.0500  0.847407       NaN

# %%
#calculate the frist two
irs1.at[0,'libor_df'] = 1/(irs1.at[0, 'Rate']*0.5+1)

def equation1(df, irs):
    sum = 0
    for i in range(len(irs)):
        if i == 0:
            sum += irs["ois_df"].iloc[i]/irs['libor_df'].iloc[i]*2
        elif i == len(irs) - 1:
            sum += irs["ois_df"].iloc[i]*irs['libor_df'].iloc[i-1]/df*2
        else:
            sum += irs["ois_df"].iloc[i]*irs['libor_df'].iloc[i-1]/irs['libor_df'].iloc[i]*2

    return sum - (irs['Rate'].iloc[-1] + 2)*np.sum(irs['ois_df'])
guess = 0.99


irs1.at[1, 'libor_df'] = fsolve(equation1, guess, args=(irs1.iloc[0:2]))[0]
irs1
# Out:
#     tenor    Rate    ois_df  libor_df
# 0     0.5  0.0250  0.998752  0.987654
# 1     1.0  0.0280  0.997009  0.972577
# 2     1.5     NaN  0.995270       NaN
# 3     2.0  0.0300  0.993531       NaN
# 4     2.5     NaN  0.991773       NaN
# 5     3.0  0.0315  0.990015       NaN
# 6     3.5     NaN  0.988066       NaN
# 7     4.0  0.0325  0.986117       NaN
# 8     4.5     NaN  0.984150       NaN
# 9     5.0  0.0330  0.982184       NaN
# 10    5.5     NaN  0.979740       NaN
# 11    6.0     NaN  0.977295       NaN
# 12    6.5     NaN  0.974850       NaN
# 13    7.0  0.0350  0.972406       NaN
# 14    7.5     NaN  0.969668       NaN
# 15    8.0     NaN  0.966929       NaN
# 16    8.5     NaN  0.964191       NaN
# 17    9.0     NaN  0.961453       NaN
# 18    9.5     NaN  0.958715       NaN
# 19   10.0  0.0370  0.955977       NaN
# 20   10.5     NaN  0.953140       NaN
# 21   11.0     NaN  0.950304       NaN
# 22   11.5     NaN  0.947467       NaN
# 23   12.0     NaN  0.944631       NaN
# 24   12.5     NaN  0.941794       NaN
# 25   13.0     NaN  0.938958       NaN
# 26   13.5     NaN  0.936121       NaN
# 27   14.0     NaN  0.933285       NaN
# 28   14.5     NaN  0.930448       NaN
# 29   15.0  0.0400  0.927611       NaN
# 30   15.5     NaN  0.924858       NaN
# 31   16.0     NaN  0.922104       NaN
# 32   16.5     NaN  0.919351       NaN
# 33   17.0     NaN  0.916597       NaN
# 34   17.5     NaN  0.913844       NaN
# 35   18.0     NaN  0.911090       NaN
# 36   18.5     NaN  0.908337       NaN
# 37   19.0     NaN  0.905583       NaN
# 38   19.5     NaN  0.902829       NaN
# 39   20.0  0.0450  0.900076       NaN
# 40   20.5     NaN  0.897442       NaN
# 41   21.0     NaN  0.894809       NaN
# 42   21.5     NaN  0.892176       NaN
# 43   22.0     NaN  0.889542       NaN
# 44   22.5     NaN  0.886909       NaN
# 45   23.0     NaN  0.884275       NaN
# 46   23.5     NaN  0.881642       NaN
# 47   24.0     NaN  0.879008       NaN
# 48   24.5     NaN  0.876375       NaN
# 49   25.0     NaN  0.873741       NaN
# 50   25.5     NaN  0.871108       NaN
# 51   26.0     NaN  0.868474       NaN
# 52   26.5     NaN  0.865841       NaN
# 53   27.0     NaN  0.863207       NaN
# 54   27.5     NaN  0.860574       NaN
# 55   28.0     NaN  0.857941       NaN
# 56   28.5     NaN  0.855307       NaN
# 57   29.0     NaN  0.852674       NaN
# 58   29.5     NaN  0.850040       NaN
# 59   30.0  0.0500  0.847407       NaN

# %%
def equation1(df, irs):
    irs1 = irs.copy()
    irs1['libor_df'].iloc[-1] = df
    irs1[['tenor', 'libor_df']] = irs1[['tenor', 'libor_df']].interpolate(method='linear')
    sum = 0
    for i in range(len(irs1)):
        if i == 0:
            sum += irs1["ois_df"].iloc[i]/irs1['libor_df'].iloc[i]*2
        else:
            sum += irs1["ois_df"].iloc[i]*irs1['libor_df'].iloc[i-1]/irs1['libor_df'].iloc[i]*2

    return sum - (irs1['Rate'].iloc[-1] + 2)*np.sum(irs1['ois_df'])
guess = 0.99

#index = irs1[pd.notna(irs1['Rate'])].index[2:]
index = irs1[pd.notna(irs1['Rate'])].index

for i in index:
    irs1.at[i, 'libor_df'] = fsolve(equation1, guess, args=(irs1.iloc[0:i+1]))[0]
#irs1.at[3, 'libor_df'] = fsolve(equation1, guess, args=(irs1.iloc[0:4]))[0]
irs1
# Out:
#     tenor    Rate    ois_df  libor_df
# 0     0.5  0.0250  0.998752  0.987654
# 1     1.0  0.0280  0.997009  0.972577
# 2     1.5     NaN  0.995270       NaN
# 3     2.0  0.0300  0.993531  0.942179
# 4     2.5     NaN  0.991773       NaN
# 5     3.0  0.0315  0.990015  0.910482
# 6     3.5     NaN  0.988066       NaN
# 7     4.0  0.0325  0.986117  0.878981
# 8     4.5     NaN  0.984150       NaN
# 9     5.0  0.0330  0.982184  0.848989
# 10    5.5     NaN  0.979740       NaN
# 11    6.0     NaN  0.977295       NaN
# 12    6.5     NaN  0.974850       NaN
# 13    7.0  0.0350  0.972406  0.784216
# 14    7.5     NaN  0.969668       NaN
# 15    8.0     NaN  0.966929       NaN
# 16    8.5     NaN  0.964191       NaN
# 17    9.0     NaN  0.961453       NaN
# 18    9.5     NaN  0.958715       NaN
# 19   10.0  0.0370  0.955977  0.692710
# 20   10.5     NaN  0.953140       NaN
# 21   11.0     NaN  0.950304       NaN
# 22   11.5     NaN  0.947467       NaN
# 23   12.0     NaN  0.944631       NaN
# 24   12.5     NaN  0.941794       NaN
# 25   13.0     NaN  0.938958       NaN
# 26   13.5     NaN  0.936121       NaN
# 27   14.0     NaN  0.933285       NaN
# 28   14.5     NaN  0.930448       NaN
# 29   15.0  0.0400  0.927611  0.551081
# 30   15.5     NaN  0.924858       NaN
# 31   16.0     NaN  0.922104       NaN
# 32   16.5     NaN  0.919351       NaN
# 33   17.0     NaN  0.916597       NaN
# 34   17.5     NaN  0.913844       NaN
# 35   18.0     NaN  0.911090       NaN
# 36   18.5     NaN  0.908337       NaN
# 37   19.0     NaN  0.905583       NaN
# 38   19.5     NaN  0.902829       NaN
# 39   20.0  0.0450  0.900076  0.408218
# 40   20.5     NaN  0.897442       NaN
# 41   21.0     NaN  0.894809       NaN
# 42   21.5     NaN  0.892176       NaN
# 43   22.0     NaN  0.889542       NaN
# 44   22.5     NaN  0.886909       NaN
# 45   23.0     NaN  0.884275       NaN
# 46   23.5     NaN  0.881642       NaN
# 47   24.0     NaN  0.879008       NaN
# 48   24.5     NaN  0.876375       NaN
# 49   25.0     NaN  0.873741       NaN
# 50   25.5     NaN  0.871108       NaN
# 51   26.0     NaN  0.868474       NaN
# 52   26.5     NaN  0.865841       NaN
# 53   27.0     NaN  0.863207       NaN
# 54   27.5     NaN  0.860574       NaN
# 55   28.0     NaN  0.857941       NaN
# 56   28.5     NaN  0.855307       NaN
# 57   29.0     NaN  0.852674       NaN
# 58   29.5     NaN  0.850040       NaN
# 59   30.0  0.0500  0.847407 -0.153675

# %%
irs1[pd.notna(irs1['Rate'])]
# Out:
#     tenor    Rate    ois_df  libor_df
# 0     0.5  0.0250  0.998752       NaN
# 1     1.0  0.0280  0.997009       NaN
# 3     2.0  0.0300  0.993531       NaN
# 5     3.0  0.0315  0.990015       NaN
# 7     4.0  0.0325  0.986117       NaN
# 9     5.0  0.0330  0.982184       NaN
# 13    7.0  0.0350  0.972406       NaN
# 19   10.0  0.0370  0.955977       NaN
# 29   15.0  0.0400  0.927611       NaN
# 39   20.0  0.0450  0.900076       NaN
# 59   30.0  0.0500  0.847407       NaN
